# %% [markdown]
# # Numerical integration
#
# ## Input:
#
# $\frac{\exp(\frac{-1}{x})}{x^{2}}, x_i = 0, 0.125, …, 1.0$
#
# <figure>
# <img src="attachment:./input_plot.png" alt="input_plot" />
# <figcaption aria-hidden="true">input_plot</figcaption>
# </figure>
#
# ## Integration results
#
# Trapezoidal             : 0.36698855751355025
# Simpson                 : 0.3654057258364105
# Richardson (Trapezoidal): 0.36540572583641057
# Richardson (Simpson)    : 0.3647814901496425
# Reference (Wolfram)     : 0.367879441171442
#
# # Numerical integration with interpolation function
#
# ## Input
#
# <figure>
# <img src="attachment:./input_interp.png" alt="input_interp" />
# <figcaption aria-hidden="true">input_interp</figcaption>
# </figure>
#
# ## Spline interpolation
#
# Plot of spline interpolation of this function:
# ![input_interp_plot](attachment:./input_interp_plot.png)
#
# Plot of sin(k*x) * f(x):
# ![input_interp_plot_sine](attachment:./input_interp_plot_sine.png)
#
# ## Integration results
#
# Trapezoidal : 0.007534612511163175
# Simpson : 0.007546859312303984
# Richardson (Trapezoidal): 0.007546859312303709
# Richardson (Simpson) : 0.007546843700769645
