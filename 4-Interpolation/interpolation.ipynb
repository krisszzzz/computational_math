# %% [markdown]
# # Interpolation
#
# Input:
# ![it](attachment:./it_input.png)
#
# ## Newton’s divided differences interpolation polynomial
#
# Interpolation: 174158769
# Function value: 179323175
# Error: 2.88 %
# ![newton_it](attachment:./newton_it.png)
#
# ## Cubic spline interpolation (using tridiagonal matrix)
#
# Interpolation: 175332357
# Function value: 179323175
# Error: 2.23 %
# ![spline_it](attachment:./spline_it.png)
#
# ## Least square method
#
# Base functions: $\varphi_i = \{1, x, x^2, x^3\}$
#
# Interpolation: 177437506
# Function value: 179323175
# Error: 1.05 %
# ![lsqm_it](attachment:./lsqm_it.png)
